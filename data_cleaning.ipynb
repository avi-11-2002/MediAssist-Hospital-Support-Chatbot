# %%
import pandas as pd

# %%
df = pd.read_csv("../dataset/raw_dataset.csv")

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#         Call_ID       Call_Timestamp  Patient_Age Patient_Gender        State  \
# 0  CALL-0000001  2025-02-27 20:09:18           33         Female       Alaska
# 1  CALL-0000002  2025-06-27 20:33:38           27           Male    Louisiana
# 2  CALL-0000003  2026-01-09 06:34:10           38           Male      Arizona
# 3  CALL-0000004  2025-09-01 10:33:37            7         Female  Connecticut
# 4  CALL-0000005  2024-10-07 16:00:57           17           Male         Iowa
#
#   Language New_or_Existing_Patient Call_Channel Caller_Relationship  \
# 0  English                Existing        Phone                Self
# 1  English                Existing        Phone                Self
# 2  English                     New        Phone           Caregiver
# 3  English                Existing        Phone              Parent
# 4  English                Existing        Phone                Self
#
#                                      Chief_Complaint  \
# ...

# %%
print(df.shape)
print(df.info())
print(df.isnull().sum())
print(df["Recommended_Department"].unique())
print(df["Recommended_Department"].value_counts())
# Out:
# (10000, 25)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Call_ID                        10000 non-null  object
#  1   Call_Timestamp                 10000 non-null  object
#  2   Patient_Age                    10000 non-null  int64
#  3   Patient_Gender                 10000 non-null  object
#  4   State                          10000 non-null  object
#  5   Language                       10000 non-null  object
#  6   New_or_Existing_Patient        10000 non-null  object
#  7   Call_Channel                   10000 non-null  object
#  8   Caller_Relationship            10000 non-null  object
#  9   Chief_Complaint                10000 non-null  object
#  10  Symptoms_Reported              10000 non-null  object
#  11  Symptom_Severity               10000 non-null  object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop(columns=['Call_ID', 'Call_Timestamp', 'State', 'Language', 'New_or_Existing_Patient', 'Call_Channel', 'Caller_Relationship', 'Call_Duration_Minutes', 'Wait_Time_Minutes', 'Repeat_Caller', 'Sentiment'])

# %%
df
# Out:
#       Patient_Age Patient_Gender  \
# 0              33         Female
# 1              27           Male
# 2              38           Male
# 3               7         Female
# 4              17           Male
# ...           ...            ...
# 9995           40         Female
# 9996           33           Male
# 9997           40           Male
# 9998           37           Male
# 9999           44         Female
#
#                                         Chief_Complaint  \
# 0                 Needs to see a doctor and agent every
# 1               Caller reports abdominal pain, vomiting
# 2     Caller reports needs specialist slot, book app...
# 3       Patient is dealing with skin lesion, acne flare
# 4            Parent says child has fatigue, weight loss
# ...                                                 ...
# 9995                 Concern about wants nurse guidance
# 9996                     Caller reports cough, vomiting
# ...

# %%
df = df.drop(columns=['Emergency_Flag','Chronic_Condition', 'Insurance_Type', 'Preferred_Appointment_Urgency', 'Prior_Hospital_Visit_30D', 'Call_Transcript_Summary'])

# %%
df
# Out:
#       Patient_Age Patient_Gender  \
# 0              33         Female
# 1              27           Male
# 2              38           Male
# 3               7         Female
# 4              17           Male
# ...           ...            ...
# 9995           40         Female
# 9996           33           Male
# 9997           40           Male
# 9998           37           Male
# 9999           44         Female
#
#                                         Chief_Complaint  \
# 0                 Needs to see a doctor and agent every
# 1               Caller reports abdominal pain, vomiting
# 2     Caller reports needs specialist slot, book app...
# 3       Patient is dealing with skin lesion, acne flare
# 4            Parent says child has fatigue, weight loss
# ...                                                 ...
# 9995                 Concern about wants nurse guidance
# 9996                     Caller reports cough, vomiting
# ...

# %%
df.shape
# Out:
# (10000, 8)

# %%
df.columns.tolist()
# Out:
# ['Patient_Age',
#  'Patient_Gender',
#  'Chief_Complaint',
#  'Symptoms_Reported',
#  'Symptom_Severity',
#  'Duration_of_Symptoms_Days',
#  'Pain_Score',
#  'Recommended_Department']

# %%
df.dtypes
# Out:
# Patient_Age                   int64
# Patient_Gender               object
# Chief_Complaint              object
# Symptoms_Reported            object
# Symptom_Severity             object
# Duration_of_Symptoms_Days     int64
# Pain_Score                    int64
# Recommended_Department       object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Patient_Age                  0
# Patient_Gender               0
# Chief_Complaint              0
# Symptoms_Reported            0
# Symptom_Severity             0
# Duration_of_Symptoms_Days    0
# Pain_Score                   0
# Recommended_Department       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Patient_Age                  0
# Patient_Gender               0
# Chief_Complaint              0
# Symptoms_Reported            0
# Symptom_Severity             0
# Duration_of_Symptoms_Days    0
# Pain_Score                   0
# Recommended_Department       0
# dtype: int64

# %%
df.describe()
# Out:
#         Patient_Age  Duration_of_Symptoms_Days    Pain_Score
# count  10000.000000               10000.000000  10000.000000
# mean      43.093500                  29.135200      4.478800
# std       22.646873                  36.973461      2.801167
# min        0.000000                   0.000000      0.000000
# 25%       26.000000                   5.000000      2.000000
# 50%       41.000000                  13.000000      5.000000
# 75%       59.000000                  42.000000      7.000000
# max       95.000000                 180.000000     10.000000

# %%
df["Recommended_Department"].nunique()
# Out:
# 17

# %%
df["Recommended_Department"].unique()
# Out:
# array(['Primary Care', 'Gastroenterology', 'Scheduling', 'Dermatology',
#        'Pediatrics', 'OB-GYN', 'Billing', 'Nurse Triage', 'Cardiology',
#        'Urgent Care', 'Emergency Department', 'Oncology', 'Mental Health',
#        'Neurology', 'Pulmonology', 'Pharmacy', 'Orthopedics'],
#       dtype=object)

# %%
df["Recommended_Department"].value_counts()
# Out:
# Recommended_Department
# Emergency Department    1514
# Primary Care            1185
# Pediatrics               759
# Nurse Triage             743
# Gastroenterology         690
# Urgent Care              644
# Orthopedics              629
# Pulmonology              487
# Cardiology               421
# Mental Health            420
# Neurology                402
# OB-GYN                   382
# Oncology                 354
# Dermatology              349
# Scheduling               348
# Billing                  341
# Pharmacy                 332
# Name: count, dtype: int64

# %%
(df["Chief_Complaint"].str.strip() == "").sum()
# Out:
# np.int64(0)

# %%
(df["Symptoms_Reported"].str.strip() == "").sum()
# Out:
# np.int64(0)

# %%
df["Patient_Gender"].value_counts()
# Out:
# Patient_Gender
# Female    4956
# Male      4770
# Other      274
# Name: count, dtype: int64

# %%
df["Symptom_Severity"].value_counts()
# Out:
# Symptom_Severity
# Medium      3895
# Low         2703
# High        2523
# Critical     879
# Name: count, dtype: int64

# %%
df["Patient_Text"] = (
    "Chief Complaint: " + df["Chief_Complaint"] +
    ". Symptoms: " + df["Symptoms_Reported"]
)

# %%
df[["Chief_Complaint", "Symptoms_Reported", "Patient_Text"]].head()
# Out:
#                                      Chief_Complaint  \
# 0              Needs to see a doctor and agent every
# 1            Caller reports abdominal pain, vomiting
# 2  Caller reports needs specialist slot, book app...
# 3    Patient is dealing with skin lesion, acne flare
# 4         Parent says child has fatigue, weight loss
#
#                                    Symptoms_Reported  \
# 0  mild fever; blood pressure follow-up; general ...
# 1              abdominal pain; vomiting; acid reflux
# 2            needs specialist slot; book appointment
# 3                            skin lesion; acne flare
# 4                               fatigue; weight loss
#
#                                         Patient_Text
# 0  Chief Complaint: Needs to see a doctor and age...
# 1  Chief Complaint: Caller reports abdominal pain...
# 2  Chief Complaint: Caller reports needs speciali...
# 3  Chief Complaint: Patient is dealing with skin ...
# 4  Chief Complaint: Parent says child has fatigue...

# %%
df = df.drop(columns=["Chief_Complaint", "Symptoms_Reported"])

# %%
df.to_csv('../dataset/processed_data.csv', index=False)


print("processed_data.csv is created successfully")
# Out:
# processed_data.csv is created successfully
